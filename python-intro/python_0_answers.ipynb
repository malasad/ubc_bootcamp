# %%
import novice
picture = novice.open("flower.png")
print 'original size:', picture.size
picture
# Out:
# original size: (240, 180)
# Picture (format: png, path: /Users/manar/Documents/bootcamp/python-intro/flower.png, modified: False)

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.cos((math.pi)/2)
# Out:
# 6.123233995736766e-17

# %%
import math as m
m.sqrt(5)
# Out:
# 2.23606797749979

# %%
from math import cos
cos(m.pi/2)
# Out:
# 6.123233995736766e-17

# %%
picture
# Out:
# Picture (format: png, path: /Users/manar/Documents/bootcamp/python-intro/flower.png, modified: False)

# %%
picture.size = (120,90)

# %%
picture
# Out:
# Picture (format: png, path: None, modified: True)

# %%
picture = novice.open("flower.png")

# %%
picture
# Out:
# Picture (format: png, path: /Users/manar/Documents/bootcamp/python-intro/flower.png, modified: False)

# %%
new_height= picture.height*(100.0/picture.width)
picture.size = (100,new_height)
picture
# Out:
# Picture (format: png, path: None, modified: True)
